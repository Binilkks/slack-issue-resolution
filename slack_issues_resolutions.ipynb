# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
#import pandas library
import pandas as pd


#read the dataset "news_dataset.json" provided and load it into dataframe "df"
df = pd.read_csv('ml_training_issues.csv')

#print the shape of data
print(df.shape)

#print the top5 rows
df.head()
# Out:
# (78, 2)
#                                               issues category
# 0  Customer is no longer receiving promotional of...  Opt-out
# 1  Customer opted out for being solicited for offers  Opt-out
# 2  Customer has removed themselves from offer not...  Opt-out
# 3  Customer no longer wishes to receive marketing...  Opt-out
# 4  Customer has chosen to stop receiving promotio...  Opt-out

# %%
df['category'].value_counts()
# Out:
# category
# Opt-out     50
# ID-Issue    20
# Unknown      8
# Name: count, dtype: int64

# %%
def preprocess(text):
    doc = nlp(text)
    filtered_tokens = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        filtered_tokens.append(token.lemma_)
    return ' '.join(filtered_tokens)

# %%
df['preprocessed_issue'] = df['issues'].apply(lambda text: preprocess(text))

# %%
df['category_id'] = df['category'].map({'Unknown': 0 , 'Opt-out': 1, 'ID-Issue': 2 })

# %%
df.head(50)
# Out:
#                                                issues  category  \
# 0   Customer is no longer receiving promotional of...   Opt-out
# 1   Customer opted out for being solicited for offers   Opt-out
# 2   Customer has removed themselves from offer not...   Opt-out
# 3   Customer no longer wishes to receive marketing...   Opt-out
# 4   Customer has chosen to stop receiving promotio...   Opt-out
# 5    Experiencing an issue with offers not appearing.   Unknown
# 6           Customer has chosen not to receive offers   Opt-out
# 7      Customer declined further promotional outreach   Opt-out
# 8   Customer prefers not to receive promotional of...   Opt-out
# 9   An update in your login ID setup is necessary,...  ID-Issue
# 10  Adjustments needed in ID setup, check with you...  ID-Issue
# 11         Customer has opted out of receiving offers   Opt-out
# 12                   Unable to view available offers.   Unknown
# 13  Modification in ID setup required, inform your...  ID-Issue
# 14  Customer prefers not to be reached for new offers   Opt-out
# 15  Customer has requested to be removed from offe...   Opt-out
# 16           Customer has disabled promotional offers   Opt-out
# 17  System requires an update in ID setup, contact...  ID-Issue
# 18         Customer has disabled promotional messages   Opt-out
# 19  Customer does not wish to be contacted for sal...   Opt-out
# 20       Customer has deactivated offer solicitations   Opt-out
# 21  Customer does not want to be solicited for offers   Opt-out
# 22  System prompts for ID setup change, notify tea...  ID-Issue
# 23  ID setup needs a change, please check with you...  ID-Issue
# 24  Customer no longer wants to receive marketing ...   Opt-out
# 25  Customer refuses further contact regarding pro...   Opt-out
# 26            Customer has revoked consent for offers   Opt-out
# 27   Customer does not wish to be targeted for offers   Opt-out
# 28  Change to ID setup needed, contact your team lead  ID-Issue
# 29  Customer has opted out of marketing communication   Opt-out
# 30             Customer has refused to receive offers   Opt-out
# 31                              Offers page is blank.   Unknown
# 32         Customer has turned off promotional offers   Opt-out
# 33  User access ID setup needs modification, conta...  ID-Issue
# 34  Customer has disabled all future promotional e...   Opt-out
# 35  User authentication setup requires changes, co...  ID-Issue
# 36         Customer is no longer interested in offers   Opt-out
# 37  Update required for ID configuration, contact ...  ID-Issue
# 38  Customer opted out of receiving promotional texts   Opt-out
# 39  ID configuration adjustment needed, discuss wi...  ID-Issue
# 40  Customer unsubscribed from promotional notific...   Opt-out
# 41  Customer has blocked marketing-related notific...   Opt-out
# 42  Customer has opted out of being contacted for ...   Opt-out
# 43     Customer prefers not to receive advertisements   Opt-out
# 44  System settings for ID need to be modified, ta...  ID-Issue
# 45    Customer requested removal from marketing lists   Opt-out
# 46        Customer has turned off offer notifications   Opt-out
# 47               Discounts and deals are not visible.   Unknown
# 48  ID settings require modification, escalate to ...  ID-Issue
# 49   Customer has disabled all offer-related messages   Opt-out
#
#                                    preprocessed_issue  category_id
# 0             customer long receive promotional offer            1
# 1                          customer opt solicit offer            1
# 2                  customer remove offer notification            1
# 3          customer long wish receive marketing email            1
# 4   customer choose stop receive promotional outreach            1
# 5                       experience issue offer appear            0
# 6                       customer choose receive offer            1
# 7               customer decline promotional outreach            1
# 8           customer prefer receive promotional offer            1
# 9          update login ID setup necessary check lead            2
# 10          adjustment need ID setup check supervisor            2
# 11                         customer opt receive offer            1
# 12                        unable view available offer            0
# 13     modification ID setup require inform team lead            2
# 14                    customer prefer reach new offer            1
# 15         customer request remove offer notification            1
# 16                customer disabled promotional offer            1
# 17        system require update ID setup contact lead            2
# 18              customer disabled promotional message            1
# 19                   customer wish contact sale offer            1
# 20             customer deactivate offer solicitation            1
# 21                        customer want solicit offer            1
# 22     system prompt ID setup change notify team lead            2
# 23               ID setup need change check team lead            2
# 24         customer long want receive marketing offer            1
# 25                  customer refuse contact promotion            1
# 26                      customer revoke consent offer            1
# 27                         customer wish target offer            1
# 28             change ID setup need contact team lead            2
# 29               customer opt marketing communication            1
# 30                      customer refuse receive offer            1
# 31                                   offer page blank            0
# 32                    customer turn promotional offer            1
# 33  user access ID setup need modification contact...            2
# 34          customer disable future promotional email            1
# 35  user authentication setup require change conta...            2
# 36                     customer long interested offer            1
# 37  update require ID configuration contact team lead            2
# 38              customer opt receive promotional text            1
# 39  ID configuration adjustment need discuss team ...            2
# 40      customer unsubscribe promotional notification            1
# 41       customer block marketing relate notification            1
# 42              customer opt contact promotional deal            1
# 43              customer prefer receive advertisement            1
# 44       system setting ID need modify talk team lead            2
# 45            customer request removal marketing list            1
# 46                   customer turn offer notification            1
# 47                              discount deal visible            0
# 48  ID setting require modification escalate team ...            2
# 49              customer disable offer relate message            1

# %%
def get_mean_vector(text):
    tokens = nlp(text)
    return np.mean([word.vector for word in tokens if word.has_vector], axis=0)
df['vector'] = df['preprocessed_issue'].apply(get_mean_vector)

# %%
print(df['category_id'])
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 73    1
# 74    2
# 75    0
# 76    1
# 77    2
# Name: category_id, Length: 78, dtype: int64

# %%
from sklearn.model_selection import train_test_split


#Do the 'train-test' splitting with test size of 20% with random state of 2022 and stratify sampling too
X_train, X_test, y_train, y_test = train_test_split(
    df.vector.values, 
    df.category_id, 
    test_size=0.2, # 20% samples will go to test dataset
    random_state=2022,
    stratify=df.category_id
)

# %%
import numpy as np

print("Shape of X_train before reshaping: ", X_train.shape)
print("Shape of X_test before reshaping: ", X_test.shape)


X_train_2d = np.stack(X_train)
X_test_2d =  np.stack(X_test)

print("Shape of X_train after reshaping: ", X_train_2d.shape)
print("Shape of X_test after reshaping: ", X_test_2d.shape)
# Out:
# Shape of X_train before reshaping:  (62,)
# Shape of X_test before reshaping:  (16,)
# Shape of X_train after reshaping:  (62, 300)
# Shape of X_test after reshaping:  (16, 300)

# %%
from sklearn.ensemble import GradientBoostingClassifier


#1. creating a GradientBoosting model object
clf = GradientBoostingClassifier()

#2. fit with all_train_embeddings and y_train
clf.fit(X_train_2d, y_train)


#3. get the predictions for all_test_embeddings and store it in y_pred
y_pred = clf.predict(X_test_2d)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.91      1.00      0.95        10
#            2       1.00      1.00      1.00         4
#
#     accuracy                           0.94        16
#    macro avg       0.97      0.83      0.87        16
# weighted avg       0.94      0.94      0.93        16

# %%
# Select one test sample
test_index = 2  # Change index to test different samples
sample_vector = X_test_2d[test_index].reshape(1, -1)  # Reshape for model
predicted_category = clf.predict(sample_vector)[0]  # Predict category

# Print result
print(f"Test Issue Vector Shape: {sample_vector.shape}")
print(f"Predicted Category ID: {predicted_category}")
print(f"Actual Category ID: {y_test.iloc[test_index]}")
# Out:
# Test Issue Vector Shape: (1, 300)
# Predicted Category ID: 0
# Actual Category ID: 0

# %%
import joblib

joblib.dump(clf, 'slack_issue_resolution_model.pkl')
# Out:
# ['slack_issue_resolution_model.pkl']

# %%
import joblib

# Load the trained model
slack_model = joblib.load('slack_issue_resolution_model.pkl')

# %%
# Select one test sample
test_index = 0  # Change index to test different samples
sample_vector = X_test_2d[test_index].reshape(1, -1)  # Reshape for model
predicted_category = slack_model.predict(sample_vector)[0]  # Predict category

# Print result
print(f"Test Issue Vector Shape: {sample_vector.shape}")
print(f"Predicted Category ID: {predicted_category}")
print(f"Actual Category ID: {y_test.iloc[test_index]}")
# Out:
# Test Issue Vector Shape: (1, 300)
# Predicted Category ID: 1
# Actual Category ID: 1

# %%
# !pip3 install flask
# Out:
# Collecting flask
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting Werkzeug>=3.1 (from flask)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from flask) (3.1.5)
# Collecting itsdangerous>=2.2 (from flask)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from flask) (8.1.8)
# Collecting blinker>=1.9 (from flask)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Downloading flask-3.1.0-py3-none-any.whl (102 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Installing collected packages: Werkzeug, itsdangerous, blinker, flask
#   WARNING: The script flask is installed in '/Library/Frameworks/Python.framework/Versions/3.10/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Werkzeug-3.1.3 blinker-1.9.0 flask-3.1.0 itsdangerous-2.2.0
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
text1 = "Customer opted out of offer"
text2 = "Customer opted out of"

doc1 = nlp(text1)
doc2 = nlp(text2)

print("Cosine Similarity:", doc1.similarity(doc2))
# Out:
# Cosine Similarity: 0.9653920991974476
